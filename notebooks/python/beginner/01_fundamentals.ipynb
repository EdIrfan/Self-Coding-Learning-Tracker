# %% [markdown]
# # Python — Beginner, Session 01: comprehensions, grouping, functions, strings, classes
#
# No dataset needed — pure Python, using small inline data structures shaped like the
# kind of records/logs you'd actually handle as a data engineer.
#
# Select the **"Python (SCLT tutor venv)"** kernel before running anything.

# %%
records = [
    {"name": "Alice", "dept": "Engineering", "salary": 95000},
    {"name": "Bob", "dept": "Sales", "salary": 62000},
    {"name": "Carol", "dept": "Engineering", "salary": 105000},
    {"name": "Dave", "dept": "Marketing", "salary": 58000},
    {"name": "Eve", "dept": "Engineering", "salary": 88000},
]
records

# %% [markdown]
# ---
# ## Q1 — List comprehension
#
# Using `records` above, write a single list comprehension that produces a list of just
# the `name` values for records where `dept == "Engineering"`. Assign it to a variable
# named `eng_names` and print it. Expected: `['Alice', 'Carol', 'Eve']`.

# %%
# your Python here

# %% [markdown]
# ---
# ## Q2 — Grouping into a dict of lists (manual, no itertools)
#
# Using `records`, build a dict named `by_dept` where each key is a distinct `dept`
# value and each value is a list of the `name`s in that department (in the order they
# appear in `records`). Do this with a plain loop and `dict.setdefault(key,
# []).append(...)` — not a library helper. Print `by_dept`. Expected:
# `{'Engineering': ['Alice', 'Carol', 'Eve'], 'Sales': ['Bob'], 'Marketing': ['Dave']}`.

# %%
# your Python here

# %% [markdown]
# ---
# ## Q3 — Function with `*args`
#
# Write a function `summarize(*numbers)` that returns a dict with keys `min`, `max`, and
# `avg` (the average rounded to 2 decimal places via `round(..., 2)`) over whatever
# numbers are passed in. Call it as `summarize(95000, 62000, 105000, 58000, 88000)` (the
# five salaries from `records` above) and print the result. Expected: `{'min': 58000,
# 'max': 105000, 'avg': 81600.0}`.

# %%
# your Python here

# %% [markdown]
# ---
# ## Q4 — String parsing
#
# Given `line = "2026-07-29|ERROR|payment-service|Timeout connecting to db"`, split it on
# `"|"` and build a dict named `parsed` with keys `date`, `level`, `service`, `message`
# mapped to the four resulting parts in order. Print `parsed`. Expected: `{'date':
# '2026-07-29', 'level': 'ERROR', 'service': 'payment-service', 'message': 'Timeout
# connecting to db'}`.

# %%
# your Python here

# %% [markdown]
# ---
# ## Q5 — Basic class
#
# Define a class `RunningStats` with an `__init__` that sets `self.values = []`, an
# `add(self, value)` method that appends to `self.values`, and an `average(self)` method
# that returns `round(sum(self.values) / len(self.values), 2)`. Instantiate it as
# `stats = RunningStats()`, loop over `[95000, 62000, 105000, 58000, 88000]` calling
# `stats.add(v)` for each, then print `stats.average()`. Expected: `81600.0`.

# %%
# your Python here

# %% [markdown]
# ---
# ## Done?
#
# Say "done" in chat once all 5 run and look right.
