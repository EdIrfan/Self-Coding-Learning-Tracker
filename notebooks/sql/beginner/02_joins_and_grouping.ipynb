# %% [markdown]
# # SQL — Beginner, Session 02: JOINs / GROUP BY / HAVING
#
# Dataset: `datasets/chinook.db`. Same rules as last time — write your SQL in each
# `query = """ ... """`, run it, check the output actually answers the question.
#
# Select the **"Python (SCLT tutor venv)"** kernel before running anything.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../../../datasets/chinook.db")

def run(query: str) -> pd.DataFrame:
    return pd.read_sql_query(query, conn)

# %% [markdown]
# ---
# ## Q1 — Basic INNER JOIN
#
# For each track, return the track's `Name` (as `TrackName`) and its album's `Title`
# (as `AlbumTitle`), by joining `Track` to `Album` on `AlbumId`. Limit to 10 rows.

# %%
query = """
-- your SQL here
SELECT 
    t1.Name AS TrackName,
    t2.Title AS AlbumTitle
FROM
    Track t1
INNER JOIN
    Album t2
ON 
    t1.AlbumId = t2.AlbumId
"""
run(query)
# Out:
#                                               TrackName  \
# 0               For Those About To Rock (We Salute You)
# 1                                     Balls to the Wall
# 2                                       Fast As a Shark
# 3                                     Restless and Wild
# 4                                  Princess of the Dawn
# ...                                                 ...
# 3498  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...
# 3499  String Quartet No. 12 in C Minor, D. 703 "Quar...
# 3500               L'orfeo, Act 3, Sinfonia (Orchestra)
# 3501  Quintet for Horn, Violin, 2 Violas, and Cello ...
# 3502                                      Koyaanisqatsi
#
#                                              AlbumTitle
# 0                 For Those About To Rock We Salute You
# 1                                     Balls to the Wall
# 2                                     Restless and Wild
# 3                                     Restless and Wild
# 4                                     Restless and Wild
# ...                                                 ...
# 3498                             Respighi:Pines of Rome
# 3499  Schubert: The Late String Quartets & String Qu...
# 3500                                Monteverdi: L'Orfeo
# 3501                              Mozart: Chamber Music
# 3502  Koyaanisqatsi (Soundtrack from the Motion Pict...
#
# [3503 rows x 2 columns]

# %% [markdown]
# ---
# ## Q2 — Three-table JOIN
#
# Extend Q1: also bring in the artist's name (`Artist.Name`, as `ArtistName`) by joining
# `Album` to `Artist` on `ArtistId`. Return `TrackName`, `AlbumTitle`, `ArtistName`, limit 10.

# %%
query = """
-- your SQL here
SELECT 
    t1.Name AS TrackName,
    t2.Title AS AlbumTitle,
    t3.Name AS ArtistName
FROM
    Track t1
INNER JOIN
    Album t2
ON 
    t1.AlbumId = t2.AlbumId
INNER JOIN
    Artist t3
ON
    t2.ArtistId = t3.ArtistId
"""
run(query)
# Out:
#                                               TrackName  \
# 0               For Those About To Rock (We Salute You)
# 1                                     Balls to the Wall
# 2                                       Fast As a Shark
# 3                                     Restless and Wild
# 4                                  Princess of the Dawn
# ...                                                 ...
# 3498  Pini Di Roma (Pinien Von Rom) \ I Pini Della V...
# 3499  String Quartet No. 12 in C Minor, D. 703 "Quar...
# 3500               L'orfeo, Act 3, Sinfonia (Orchestra)
# 3501  Quintet for Horn, Violin, 2 Violas, and Cello ...
# 3502                                      Koyaanisqatsi
#
#                                              AlbumTitle  \
# 0                 For Those About To Rock We Salute You
# 1                                     Balls to the Wall
# 2                                     Restless and Wild
# 3                                     Restless and Wild
# 4                                     Restless and Wild
# ...                                                 ...
# 3498                             Respighi:Pines of Rome
# 3499  Schubert: The Late String Quartets & String Qu...
# 3500                                Monteverdi: L'Orfeo
# 3501                              Mozart: Chamber Music
# 3502  Koyaanisqatsi (Soundtrack from the Motion Pict...
#
#                                              ArtistName
# 0                                                 AC/DC
# 1                                                Accept
# 2                                                Accept
# 3                                                Accept
# 4                                                Accept
# ...                                                 ...
# 3498                                     Eugene Ormandy
# 3499                             Emerson String Quartet
# 3500  C. Monteverdi, Nigel Rogers - Chiaroscuro; Lon...
# 3501                                      Nash Ensemble
# 3502                              Philip Glass Ensemble
#
# [3503 rows x 3 columns]

# %% [markdown]
# ---
# ## Q3 — JOIN + GROUP BY + COUNT
#
# Count how many tracks exist in each genre. Join `Track` to `Genre` **on `GenreId`**
# (that's the shared key — neither table has a `GenreName` column; the genre's name is
# just `Genre.Name`). Group by `Genre.Name`, return it aliased as `Genre` along with
# `NumTracks`, ordered by `NumTracks` descending.

# %%
query = """
-- your SQL here
SELECT
    GenreName,
    COUNT(NumTracks) AS NumTracks
FROM
    Track t1
INNER JOIN
    Genre t2
ON
    t1.GenreName = t2.GenreName

"""
run(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/GitHub/Self-Coding-Learning-Tracker/Self-Coding-Learning-Tracker/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such column: GenreName
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 14
#      10 ON
#      11     t1.GenreName = t2.GenreName
#      12
#      13 """
# ---> 14 run(query)
#
# Cell In[3], line 7, in run(query)
#       6 def run(query: str) -> pd.DataFrame:
# ----> 7     return pd.read_sql_query(query, conn)
#
# File ~/GitHub/Self-Coding-Learning-Tracker/Self-Coding-Learning-Tracker/.venv/lib/python3.12/site-packages/pandas/io/sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~/GitHub/Self-Coding-Learning-Tracker/Self-Coding-Learning-Tracker/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~/GitHub/Self-Coding-Learning-Tracker/Self-Coding-Learning-Tracker/.venv/lib/python3.12/site-packages/pandas/io/sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql '
# -- your SQL here
# SELECT
#     GenreName,
#     COUNT(NumTracks) AS NumTracks
# FROM
#     Track t1
# INNER JOIN
#     Genre t2
# ON
#     t1.GenreName = t2.GenreName
#
# ': no such column: GenreName

# %% [markdown]
# ---
# ## Q4 — GROUP BY + SUM (no join needed)
#
# From the `Invoice` table, compute total amount spent per customer: `CustomerId` and
# `TotalSpent` (sum of `Total`), ordered by `TotalSpent` descending, top 5 only.

# %%
query = """
-- your SQL here
"""
run(query)

# %% [markdown]
# ---
# ## Q5 — HAVING (filter on an aggregate)
#
# Same setup as Q3 (tracks per genre), but this time only return genres with **more than
# 100 tracks**. Remember: `WHERE` can't filter on an aggregate — you need `HAVING`.

# %%
query = """
-- your SQL here
"""
run(query)

# %% [markdown]
# ---
# ## Done?
#
# Say "done" in chat once all 5 run and look right — Claude will check the real output,
# update the tracker, and hand you the next set automatically.
